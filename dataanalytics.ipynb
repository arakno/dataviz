# %%
import pandas as pd
import seaborn as sns # for dataviz (based on matplotlib)

FILEPATH = 'data/AB_NYC_2019.csv'
listings_df = pd.read_csv(FILEPATH)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c882ea4742b3> in <module>
#       1 import pandas as pd
# ----> 2 import seaborn as sns # for dataviz (based on matplotlib)
#       3
#       4 FILEPATH = 'data/AB_NYC_2019.csv'
#       5 listings_df = pd.read_csv(FILEPATH)
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
listings_df.shape
# Out:
# (48895, 16)

# %%
listings_df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
listings_df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
# Clean data (show how many nulls found in each column)
listings_df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# boolean indexing
listings_df[listings_df['price'] < 100]
# Out:
#                                                     name    host_id  \
# 3                        Cozy Entire Floor of Brownstone       4869
# 4       Entire Apt: Spacious Studio/Loft by central park       7192
# 6                                        BlissArtsSpace!       7356
# 7                       Large Furnished Room Near B'way        8967
# 8                     Cozy Clean Guest Room - Family Apt       7490
# ...                                                  ...        ...
# 48889                                 QUIT PRIVATE HOUSE  107716952
# 48890    Charming one bedroom - newly renovated rowhouse    8232441
# 48891      Affordable room in Bushwick/East Williamsburg    6570630
# 48893               43rd St. Time Square-cozy single bed   30985759
# 48894  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
#       neighbourhood_group       neighbourhood  latitude  longitude  \
# 3                Brooklyn        Clinton Hill  40.68514  -73.95976
# ...

# %%
listings_df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
listings_df['neighbourhood_group'].value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
listings_df['neighbourhood'].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Chart with Seaborn
ordered_neighbourhood = listings_df['neighbourhood_group'].value_counts().index
sns.countplot(data=listings_df, x='neighbourhood_group', order=ordered_neighbourhood)
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='count'>

# %%
# distribution of flat prices
sns.distplot(listings_df['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
# remove outliars
affordable_df = listings_df['price'] <= 500
sns.distplot(affordable_df)
# Out:
# <AxesSubplot:xlabel='price'>

# %%
affordable_df.mean()
# Out:
# 0.9786481235300133

# %%
# sns.violinplot(data=affordable_df, x='neighbourhood_group', y='price')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-4e282caa0cc5> in <module>
# ----> 1 sns.violinplot(data=affordable_df, x='neighbourhood', y='price')
#
# ~/miniconda3/lib/python3.8/site-packages/seaborn/categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2382                ax=None, **kwargs):
#    2383
# -> 2384     plotter = _ViolinPlotter(x, y, hue, data, order, hue_order,
#    2385                              bw, cut, scale, scale_hue, gridsize,
#    2386                              width, inner, split, dodge, orient, linewidth,
#
# ...

# %%
# Drop some columns
columns_to_drop = ['id', 'host_name', 'last_review']
listings_df.drop(columns_to_drop, axis='columns', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-98f60b163e5d> in <module>
#       1 columns_to_drop = ['id', 'host_name', 'last_review']
# ----> 2 listings_df.drop(columns_to_drop, axis="columns", inplace=True)
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4158                 weight  1.0     0.8
#    4159         """
# -> 4160         return super().drop(
#    4161             labels=labels,
#    4162             axis=axis,
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3876         for axis, labels in axes.items():
#    3877             if labels is not None:
# -> 3878                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3879
# ...
